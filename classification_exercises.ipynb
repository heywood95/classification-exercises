# %% [markdown]
# # Exercises - Data Acquisition

# %% [markdown]
# 4. In a jupyter notebook, classification_exercises.ipynb, use a python module (pydata or seaborn datasets) containing datasets as a source from the iris data. Create a pandas dataframe, df_iris, from this data.

# %%
import env
import pandas as pd
import os
import seaborn as sns
import numpy as np
from pydataset import data


def get_connection(db, username=env.username, host=env.host, password=env.password):
    return f'mysql+pymysql://{username}:{password}@{host}/{db}'

df_iris = pd.read_sql('SELECT * FROM measurements', get_connection('iris_db'))

df_iris.head()
# Out:
#    measurement_id  sepal_length  sepal_width  petal_length  petal_width  \
# 0               1           5.1          3.5           1.4          0.2
# 1               2           4.9          3.0           1.4          0.2
# 2               3           4.7          3.2           1.3          0.2
# 3               4           4.6          3.1           1.5          0.2
# 4               5           5.0          3.6           1.4          0.2
#
#    species_id
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1

# %%
def get_iris_data():
    return pd.read_sql('SELECT * FROM measurements', get_connection('iris_db'))

# %%
def get_iris_data():
    filename = "iris.csv"

    if os.path.isfile(filename):
        return pd.read_csv(filename)
    
    else:
        df_iris = pd.read_sql('SELECT * FROM measurements', get_connection('iris_db'))

        
        df_iris.to_file(filename)

        
        return df_iris

# %% [markdown]
# - print the first 3 rows

# %%
df_iris.head(3)
# Out:
#    measurement_id  sepal_length  sepal_width  petal_length  petal_width  \
# 0               1           5.1          3.5           1.4          0.2
# 1               2           4.9          3.0           1.4          0.2
# 2               3           4.7          3.2           1.3          0.2
#
#    species_id
# 0           1
# 1           1
# 2           1

# %% [markdown]
# - print the number of rows and columns (shape)

# %%
df_iris.shape
# Out:
# (150, 6)

# %% [markdown]
# - print the column names

# %%
df_iris.columns
# Out:
# Index(['measurement_id', 'sepal_length', 'sepal_width', 'petal_length',
#        'petal_width', 'species_id'],
#       dtype='object')

# %% [markdown]
# - print the data type of each column

# %%
df_iris.dtypes
# Out:
# measurement_id      int64
# sepal_length      float64
# sepal_width       float64
# petal_length      float64
# petal_width       float64
# species_id          int64
# dtype: object

# %% [markdown]
# - print the summary statistics for each of the numeric variables

# %%
df_iris.describe()
# Out:
#        measurement_id  sepal_length  sepal_width  petal_length  petal_width  \
# count      150.000000    150.000000   150.000000    150.000000   150.000000
# mean        75.500000      5.843333     3.057333      3.758000     1.199333
# std         43.445368      0.828066     0.435866      1.765298     0.762238
# min          1.000000      4.300000     2.000000      1.000000     0.100000
# 25%         38.250000      5.100000     2.800000      1.600000     0.300000
# 50%         75.500000      5.800000     3.000000      4.350000     1.300000
# 75%        112.750000      6.400000     3.300000      5.100000     1.800000
# max        150.000000      7.900000     4.400000      6.900000     2.500000
#
#        species_id
# count  150.000000
# mean     2.000000
# std      0.819232
# min      1.000000
# 25%      1.000000
# 50%      2.000000
# 75%      3.000000
# max      3.000000

# %% [markdown]
# 5. Read the data from this google sheet into a dataframe, df_google.

# %%
sheet_url = 'https://docs.google.com/spreadsheets/d/1Uhtml8KY19LILuZsrDtlsHHDC9wuDGUSe8LTEwvdI5g/edit#gid=341089357'    

csv_export_url = sheet_url.replace('/edit#gid=', '/export?format=csv&gid=')

df_google = pd.read_csv(csv_export_url)
df_google.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %% [markdown]
# - print the first 3 rows

# %%
df_google.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %% [markdown]
# - print the number of rows and columns

# %%
df_google.shape
# Out:
# (891, 12)

# %% [markdown]
# - print the column names

# %%
df_google.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# - print the data type of each column

# %%
df_google.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# - print the summary statistics for each of the numeric variables

# %%
df_google.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# - print the unique values for each of your categorical variables

# %%
df_google.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
for col in df_google.columns:
    print(col)
if df_google[col].dtypes == 'object':
    print(f'{col} has {df_google[col].nunique()} unique values.')
# Out:
# PassengerId
# Survived
# Pclass
# Name
# Sex
# Age
# SibSp
# Parch
# Ticket
# Fare
# Cabin
# Embarked
# Embarked has 3 unique values.

# %% [markdown]
# 6. Download the previous exercise's file into an excel (File → Download → Microsoft Excel). Read the downloaded file into a dataframe named df_excel.

# %%
df_excel = pd.read_excel('train.xlsx', sheet_name='train')

# %%
df_excel.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
df_excel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# - assign the first 100 rows to a new dataframe, df_excel_sample

# %%
df_excel_sample = df_excel.head(100)

# %% [markdown]
# - print the number of rows of your original dataframe

# %%
len(df_excel)
df_excel_sample.shape[0]
# Out:
# 100

# %% [markdown]
# - print the first 5 column names

# %%
n = 5
df_excel_sample.iloc[:, :n]
df_excel.columns[0:5]
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex'], dtype='object')

# %% [markdown]
# - print the column names that have a data type of object

# %%
list(df_excel_sample.select_dtypes(['object']).columns)
# Out:
# ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked']

# %% [markdown]
# - compute the range for each of the numeric variables.

# %%
df_excel_sample.nunique()
# Out:
# PassengerId    100
# Survived         2
# Pclass           3
# Name           100
# Sex              2
# Age             45
# SibSp            6
# Parch            5
# Ticket          97
# Fare            69
# Cabin           19
# Embarked         3
# dtype: int64

# %%
titanic_stats = df_excel[['Age', 'Fare']]
titanic_stats['range'] = titanic_stats['max'] - titanic_stats['min']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'max'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# 1. Make a function named get_titanic_data that returns the titanic data from the codeup data science database as a pandas data frame. Obtain your data from the Codeup Data Science Database.

# %%
def get_titanic_data():

    filename = "titanic.csv"

    if os.path.isfile(filename):
        return pd.read_csv(filename)
    
    else:
        df_titanic = pd.read_sql('SELECT * FROM passengers', get_connection('titanic_db'))

        
        df_titanic.to_file(filename)

        
        return df_titanic

# %% [markdown]
# 2. Make a function named get_iris_data that returns the data from the iris_db on the codeup data science database as a pandas data frame. The returned data frame should include the actual name of the species in addition to the species_ids. Obtain your data from the Codeup Data Science Database.

# %%
def get_iris_data():
    filename = "iris.csv"

    if os.path.isfile(filename):
        return pd.read_csv(filename)
    
    else:
        df_iris = pd.read_sql('SELECT * FROM measurements JOIN species', get_connection('iris_db'))

        
        df_iris.to_file(filename)

        
        return df_iris

# %% [markdown]
# 3. Make a function named get_telco_data that returns the data from the telco_churn database in SQL. In your SQL, be sure to join contract_types, internet_service_types, payment_types tables with the customers table, so that the resulting dataframe contains all the contract, payment, and internet service options. Obtain your data from the Codeup Data Science Database.

# %%
def get_telco_data():
    filename = "telco.csv"

    if os.path.isfile(filename):
        return pd.read_csv(filename)
    
    else:
        df_telco = pd.read_sql('SELECT * FROM customers JOIN contract_types JOIN internet_service_types JOIN payment_types', get_connection('telco_churn'))

        
        df_telco.to_file(filename)

        
        return df_telco

# %% [markdown]
# 4. Once you've got your get_titanic_data, get_iris_data, and get_telco_data functions written, now it's time to add caching to them. To do this, edit the beginning of the function to check for the local filename of telco.csv, titanic.csv, or iris.csv. If they exist, use the .csv file. If the file doesn't exist, then produce the SQL and pandas necessary to create a dataframe, then write the dataframe to a .csv file with the appropriate name.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# import splitting and imputing functions
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer

# turn off pink boxes for demo
import warnings
warnings.filterwarnings("ignore")

# import our own acquire module
import acquire

# %% [markdown]
# # Exercises - Data Preperation

# %% [markdown]
# Exercises
#
# The end product of this exercise should be the specified functions in a python script named prepare.py. Do these in your classification_exercises.ipynb first, then transfer to the prepare.py file.
#
# This work should all be saved in your local classification-exercises repo. Then add, commit, and push your changes.
#
# Using the Iris Data:

# %% [markdown]
# 1. Use the function defined in acquire.py to load the iris data.

# %%
import env
import pandas as pd
import os
import seaborn as sns
import numpy as np
from pydataset import data
from env import get_connection

import matplotlib.pyplot as plt

# import splitting and imputing functions
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer

# turn off pink boxes for demo
import warnings
warnings.filterwarnings("ignore")

# import our own acquire module
import acquire

# %%
iris = acquire.get_iris_data()

# %% [markdown]
# 2. Drop the species_id and measurement_id columns.

# %%
iris.head()
# Out:
#    Unnamed: 0  measurement_id  sepal_length  sepal_width  petal_length  \
# 0           0               1           5.1          3.5           1.4
# 1           1               1           5.1          3.5           1.4
# 2           2               1           5.1          3.5           1.4
# 3           3               2           4.9          3.0           1.4
# 4           4               2           4.9          3.0           1.4
#
#    petal_width  species_id  species_id.1 species_name
# 0          0.2           1             3    virginica
# 1          0.2           1             2   versicolor
# 2          0.2           1             1       setosa
# 3          0.2           1             3    virginica
# 4          0.2           1             2   versicolor

# %%
cols_to_drop = ['Unnamed: 0', 'measurement_id', 'species_id', 'species_id.1']
iris = iris.drop(columns=cols_to_drop)
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species_name
# 0           5.1          3.5           1.4          0.2    virginica
# 1           5.1          3.5           1.4          0.2   versicolor
# 2           5.1          3.5           1.4          0.2       setosa
# 3           4.9          3.0           1.4          0.2    virginica
# 4           4.9          3.0           1.4          0.2   versicolor

# %% [markdown]
# 3. Rename the species_name column to just species.

# %%
iris.rename(columns = {'species_name': 'species'}, inplace=True)
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width     species
# 0           5.1          3.5           1.4          0.2   virginica
# 1           5.1          3.5           1.4          0.2  versicolor
# 2           5.1          3.5           1.4          0.2      setosa
# 3           4.9          3.0           1.4          0.2   virginica
# 4           4.9          3.0           1.4          0.2  versicolor

# %% [markdown]
# 4. Create dummy variables of the species name and concatenate onto the iris dataframe. (This is for practice, we don't always have to encode the target, but if we used species as a feature, we would need to encode it).

# %%
dummy_iris = pd.get_dummies(iris.species, drop_first=True)
iris = pd.concat([iris, dummy_iris], axis=1)
iris.head(1)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width    species  \
# 0           5.1          3.5           1.4          0.2  virginica
#
#    versicolor  virginica
# 0           0          1

# %% [markdown]
# 5. Create a function named prep_iris that accepts the untransformed iris data, and returns the data with the transformations above applied.

# %%
def prep_iris(iris):
    
    cols_to_drop = ['Unnamed: 0', 'measurement_id', 'species_id', 'species_id.1']
    iris = iris.drop(columns=cols_to_drop)
    iris.rename(columns = {'species_name': 'species'}, inplace=True)
    dummy_iris = pd.get_dummies(iris.species, drop_first=True)
    iris = pd.concat([iris, dummy_iris], axis=1)
    
    return iris

# %%
prep_iris(acquire.get_iris_data())
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species  \
# 0             5.1          3.5           1.4          0.2   virginica
# 1             5.1          3.5           1.4          0.2  versicolor
# 2             5.1          3.5           1.4          0.2      setosa
# 3             4.9          3.0           1.4          0.2   virginica
# 4             4.9          3.0           1.4          0.2  versicolor
# ..            ...          ...           ...          ...         ...
# 445           6.2          3.4           5.4          2.3  versicolor
# 446           6.2          3.4           5.4          2.3      setosa
# 447           5.9          3.0           5.1          1.8   virginica
# 448           5.9          3.0           5.1          1.8  versicolor
# 449           5.9          3.0           5.1          1.8      setosa
#
#      versicolor  virginica
# 0             0          1
# 1             1          0
# 2             0          0
# ...

# %% [markdown]
# Using the Titanic dataset
#
# 1. Use the function defined in acquire.py to load the Titanic data.

# %%
titanic = acquire.get_titanic_data()
titanic.head()
# Out:
#    Unnamed: 0  passenger_id  survived  pclass     sex   age  sibsp  parch  \
# 0           0             0         0       3    male  22.0      1      0
# 1           1             1         1       1  female  38.0      1      0
# 2           2             2         1       3  female  26.0      0      0
# 3           3             3         1       1  female  35.0      1      0
# 4           4             4         0       3    male  35.0      0      0
#
#       fare embarked  class deck  embark_town  alone
# 0   7.2500        S  Third  NaN  Southampton      0
# 1  71.2833        C  First    C    Cherbourg      0
# 2   7.9250        S  Third  NaN  Southampton      1
# 3  53.1000        S  First    C  Southampton      0
# 4   8.0500        S  Third  NaN  Southampton      1

# %% [markdown]
# 2. Drop any unnecessary, unhelpful, or duplicated columns.

# %%
cols_to_drop = ['deck', 'embarked', 'class', 'age']
titanic = titanic.drop(columns=cols_to_drop)
titanic.head()
# Out:
#    Unnamed: 0  passenger_id  survived  pclass     sex  sibsp  parch     fare  \
# 0           0             0         0       3    male      1      0   7.2500
# 1           1             1         1       1  female      1      0  71.2833
# 2           2             2         1       3  female      0      0   7.9250
# 3           3             3         1       1  female      1      0  53.1000
# 4           4             4         0       3    male      0      0   8.0500
#
#    embark_town  alone
# 0  Southampton      0
# 1    Cherbourg      0
# 2  Southampton      1
# 3  Southampton      0
# 4  Southampton      1

# %% [markdown]
# 3. Encode the categorical columns. Create dummy variables of the categorical columns and concatenate them onto the dataframe.

# %%
dummy_titanic = pd.get_dummies(titanic[['sex','embark_town']], dummy_na=False, drop_first=[True, True])
titanic = pd.concat([titanic, dummy_titanic], axis=1)
titanic.head(1)
# Out:
#    Unnamed: 0  passenger_id  survived  pclass   sex  sibsp  parch  fare  \
# 0           0             0         0       3  male      1      0  7.25
#
#    embark_town  alone  sex_male  embark_town_Queenstown  \
# 0  Southampton      0         1                       0
#
#    embark_town_Southampton  sex_male  embark_town_Queenstown  \
# 0                        1         1                       0
#
#    embark_town_Southampton  sex_male  embark_town_Queenstown  \
# 0                        1         1                       0
#
#    embark_town_Southampton
# 0                        1

# %% [markdown]
# 4. Create a function named prep_titanic that accepts the raw titanic data, and returns the data with the transformations above applied.

# %%
def prep_titanic(df):
    
    cols_to_drop = ['deck', 'embarked', 'class', 'age']
    titanic = titanic.drop(columns=cols_to_drop)
    dummy_titanic = pd.get_dummies(titanic[['sex','embark_town']], dummy_na=False, drop_first=[True, True])
    titanic = pd.concat([titanic, dummy_titanic], axis=1)
    titanic.dropna()
    return titanic

# %%
df = acquire.get_titanic_data()
df.head(2)
# Out:
#    Unnamed: 0  passenger_id  survived  pclass     sex   age  sibsp  parch  \
# 0           0             0         0       3    male  22.0      1      0
# 1           1             1         1       1  female  38.0      1      0
#
#       fare embarked  class deck  embark_town  alone
# 0   7.2500        S  Third  NaN  Southampton      0
# 1  71.2833        C  First    C    Cherbourg      0

# %% [markdown]
# Using the Telco dataset
#
# 1. Use the function defined in acquire.py to load the Telco data.

# %%
telco = acquire.get_telco_data()
telco.head()
# Out:
#    Unnamed: 0 customer_id  gender  senior_citizen partner dependents  tenure  \
# 0           0  0002-ORFBO  Female               0     Yes        Yes       9
# 1           1  0002-ORFBO  Female               0     Yes        Yes       9
# 2           2  0002-ORFBO  Female               0     Yes        Yes       9
# 3           3  0002-ORFBO  Female               0     Yes        Yes       9
# 4           4  0002-ORFBO  Female               0     Yes        Yes       9
#
#   phone_service multiple_lines  internet_service_type_id  ... payment_type_id  \
# 0           Yes             No                         1  ...               2
# 1           Yes             No                         1  ...               2
# 2           Yes             No                         1  ...               2
# 3           Yes             No                         1  ...               2
# 4           Yes             No                         1  ...               2
#
# ...

# %%
telco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253548 entries, 0 to 253547
# Data columns (total 28 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Unnamed: 0                  253548 non-null  int64
#  1   customer_id                 253548 non-null  object
#  2   gender                      253548 non-null  object
#  3   senior_citizen              253548 non-null  int64
#  4   partner                     253548 non-null  object
#  5   dependents                  253548 non-null  object
#  6   tenure                      253548 non-null  int64
#  7   phone_service               253548 non-null  object
#  8   multiple_lines              253548 non-null  object
#  9   internet_service_type_id    253548 non-null  int64
#  10  online_security             253548 non-null  object
#  11  online_backup               253548 non-null  object
#  12  device_protection           253548 non-null  object
# ...

# %% [markdown]
# 2. Drop any unnecessary, unhelpful, or duplicated columns. This could mean dropping foreign key columns but keeping the corresponding string values, for example.

# %%
cols_to_drop = ['contract_type_id', 'internet_service_type_id', 'payment_type_id']
telco = telco.drop(columns=cols_to_drop)
telco.head()
# Out:
#    Unnamed: 0 customer_id  gender  senior_citizen partner dependents  tenure  \
# 0           0  0002-ORFBO  Female               0     Yes        Yes       9
# 1           1  0002-ORFBO  Female               0     Yes        Yes       9
# 2           2  0002-ORFBO  Female               0     Yes        Yes       9
# 3           3  0002-ORFBO  Female               0     Yes        Yes       9
# 4           4  0002-ORFBO  Female               0     Yes        Yes       9
#
#   phone_service multiple_lines online_security  ... paperless_billing  \
# 0           Yes             No              No  ...               Yes
# 1           Yes             No              No  ...               Yes
# 2           Yes             No              No  ...               Yes
# 3           Yes             No              No  ...               Yes
# 4           Yes             No              No  ...               Yes
#
#   monthly_charges total_charges churn contract_type_id.1   contract_type  \
# ...

# %% [markdown]
# 3. Encode the categorical columns. Create dummy variables of the categorical columns and concatenate them onto the dataframe.

# %%
dummy_telco = pd.get_dummies(telco[['gender','partner', 'dependents', 'phone_service', 'multiple_lines', 'online_security', 'online_backup', 'tech_support', 'streaming_tv', 'streaming_movies', 'paperless_billing', 'churn']], dummy_na=False, drop_first=[True, True])
telco = pd.concat([telco, dummy_telco], axis=1)
telco.head(1)
# Out:
#    Unnamed: 0 customer_id  gender  senior_citizen partner dependents  tenure  \
# 0           0  0002-ORFBO  Female               0     Yes        Yes       9
#
#   phone_service multiple_lines online_security  ...  \
# 0           Yes             No              No  ...
#
#   online_backup_No internet service online_backup_Yes  \
# 0                                 0                 1
#
#   tech_support_No internet service tech_support_Yes  \
# 0                                0                1
#
#   streaming_tv_No internet service streaming_tv_Yes  \
# 0                                0                1
#
#    streaming_movies_No internet service streaming_movies_Yes  \
# 0                                     0                    0
#
#   paperless_billing_Yes  churn_Yes
# 0                     1          0
#
# [1 rows x 43 columns]

# %% [markdown]
# 4. Create a function named prep_telco that accepts the raw telco data, and returns the data with the transformations above applied.

# %%
def prep_telco(telco):
    
    cols_to_drop = ['contract_type_id', 'internet_service_type_id', 'payment_type_id']
    telco = telco.drop(columns=cols_to_drop)
    dummy_telco = pd.get_dummies(telco[['gender','partner', 'dependents', 'phone_service', 'multiple_lines', 'online_security', 'online_backup', 'tech_support', 'streaming_tv', 'streaming_movies', 'paperless_billing', 'churn']], dummy_na=False, drop_first=[True, True])
    telco = pd.concat([telco, dummy_telco], axis=1)
    return telco

# %%
prep_telco(acquire.get_telco_data())
# Out:
#         Unnamed: 0 customer_id  gender  senior_citizen partner dependents  \
# 0                0  0002-ORFBO  Female               0     Yes        Yes
# 1                1  0002-ORFBO  Female               0     Yes        Yes
# 2                2  0002-ORFBO  Female               0     Yes        Yes
# 3                3  0002-ORFBO  Female               0     Yes        Yes
# 4                4  0002-ORFBO  Female               0     Yes        Yes
# ...            ...         ...     ...             ...     ...        ...
# 253543      253543  9995-HOTOH    Male               0     Yes        Yes
# 253544      253544  9995-HOTOH    Male               0     Yes        Yes
# 253545      253545  9995-HOTOH    Male               0     Yes        Yes
# 253546      253546  9995-HOTOH    Male               0     Yes        Yes
# 253547      253547  9995-HOTOH    Male               0     Yes        Yes
#
#         tenure phone_service    multiple_lines online_security  ...  \
# ...

# %% [markdown]
# Split your data
#
# 1. Write a function to split your data into train, test and validate datasets. Add this function to prepare.py.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# import splitting and imputing functions
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer

# turn off pink boxes for demo
import warnings
warnings.filterwarnings("ignore")

# import our own acquire module
import acquire

# %%
train, test = train_test_split(telco, 
                               train_size = 0.8,
                               random_state=42,
                              stratify=telco.churn)

# %%
train, val = train_test_split(train,
                             train_size = 0.7,
                             random_state=42,
                             stratify=train.churn)

# %%
def split_data(df, target=''):
    
    train, test = train_test_split(df, 
                               train_size = 0.8,
                               random_state=1349,
                              stratify=df[target])
    train, val = train_test_split(train,
                             train_size = 0.7,
                             random_state=1349,
                             stratify=train[target])
    return train, val, test

# %% [markdown]
# 2. Run the function in your notebook on the Iris dataset, returning 3 datasets, train_iris, validate_iris and test_iris.

# %%
iris = acquire.get_iris_data()

# %%
train, validate, test = split_data(iris, target='species_name')

# %%
train.head()
# Out:
#      Unnamed: 0  measurement_id  sepal_length  sepal_width  petal_length  \
# 249         249              84           6.0          2.7           5.1
# 269         269              90           5.5          2.5           4.0
# 36           36              13           4.8          3.0           1.4
# 267         267              90           5.5          2.5           4.0
# 445         445             149           6.2          3.4           5.4
#
#      petal_width  species_id  species_id.1 species_name
# 249          1.6           2             3    virginica
# 269          1.3           2             1       setosa
# 36           0.1           1             3    virginica
# 267          1.3           2             3    virginica
# 445          2.3           3             2   versicolor

# %%
train.size, validate.size, test.size
# Out:
# (2259, 981, 810)

# %% [markdown]
# 3. Run the function on the Titanic dataset, returning 3 datasets, train_titanic, validate_titanic and test_titanic.

# %%
titanic_train, titanic_val, titanic_test = split_data(
titanic, target='survived')

# %%
titanic_train.size, titanic_val.size, titanic_test.size
# Out:
# (9462, 4066, 3401)

# %% [markdown]
# 4. Run the function on the Telco dataset, returning 3 datasets, train_telco, validate_telco and test_telco.

# %%
telco_train, telco_val, telco_test = split_data(
telco, target='churn')

# %%
telco_train.size, telco_val.size, telco_test.size
# Out:
# (6105398, 2616636, 2180530)

# %% [markdown]
# # Exercises - Exploratory Analysis

# %% [markdown]
# Part 1
# Continue in your classification_exercises.ipynb notebook. As always, add, commit, and push your changes.
#
# Section 1 - iris_db: Using iris data from our mySQL server and the methods used in the lesson above:

# %% [markdown]
# 1. Acquire, prepare & split your data.

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.model_selection import train_test_split
import env

np.random.seed(123)

# %%
import env

def get_connection(db, user=env.username, host=env.host, password=env.password):
    return f'mysql+pymysql://{user}:{password}@{host}/{db}'

def get_iris():
    my_query="SELECT * FROM measurements JOIN species"
    df = pd.read_sql(my_query, get_connection('iris_db'))
    return df

# %%
iris = get_iris()
iris.head(2)
# Out:
#    measurement_id  sepal_length  sepal_width  petal_length  petal_width  \
# 0               1           5.1          3.5           1.4          0.2
# 1               1           5.1          3.5           1.4          0.2
#
#    species_id  species_id species_name
# 0           1           3    virginica
# 1           1           2   versicolor

# %%
iris.isna().sum()
# Out:
# measurement_id    0
# sepal_length      0
# sepal_width       0
# petal_length      0
# petal_width       0
# species_id        0
# species_id        0
# species_name      0
# dtype: int64

# %%
def prep_iris(iris):
    
    cols_to_drop = ['measurement_id', 'species_id']
    iris = iris.drop(columns=cols_to_drop)
    iris.rename(columns = {'species_name': 'species'}, inplace=True)
    dummy_iris = pd.get_dummies(iris.species, drop_first=True)
    iris = pd.concat([iris, dummy_iris], axis=1)
    
    return iris

# %%
iris = prep_iris(iris)
iris.head(2)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width     species  \
# 0           5.1          3.5           1.4          0.2   virginica
# 1           5.1          3.5           1.4          0.2  versicolor
#
#    versicolor  virginica
# 0           0          1
# 1           1          0

# %%
def train_validate_test_split(iris, target, seed=123):
    
    train_validate, test = train_test_split(iris, test_size=0.2, 
                                            random_state=seed, 
                                            stratify=iris[target])
    train, validate = train_test_split(train_validate, test_size=0.3, 
                                       random_state=seed,
                                       stratify=train_validate[target])
    return train, validate, test

# %%
train, validate, test = train_validate_test_split(iris, target='species')
train.shape, validate.shape, test.shape
# Out:
# ((252, 7), (108, 7), (90, 7))

# %% [markdown]
# # Review

# %%
import warnings
warnings.filterwarnings("ignore")

# imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.model_selection import train_test_split
import env

# %%
# Planning: Can we detrmine

# %%
def get_connection(db, user=env.username, host=env.host, password=env.password):
    return f'mysql+pymysql://{user}:{password}@{host}/{db}'

def get_iris():
    my_query="SELECT * FROM measurements JOIN species"
    df = pd.read_sql(my_query, get_connection('iris_db'))
    return df

iris = get_iris()
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   measurement_id  450 non-null    int64
#  1   sepal_length    450 non-null    float64
#  2   sepal_width     450 non-null    float64
#  3   petal_length    450 non-null    float64
#  4   petal_width     450 non-null    float64
#  5   species_id      450 non-null    int64
#  6   species_id      450 non-null    int64
#  7   species_name    450 non-null    object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 28.2+ KB

# %%
def train_validate_test_split(iris, target, seed=123):
    
    train_validate, test = train_test_split(iris, test_size=0.2, 
                                            random_state=seed, 
                                            stratify=iris[target])
    train, validate = train_test_split(train_validate, test_size=0.3, 
                                       random_state=seed,
                                       stratify=train_validate[target])
    return train, validate, test
train, validate, test
# Out:
# (     sepal_length  sepal_width  petal_length  petal_width     species  \
#  72            4.8          3.4           1.9          0.2   virginica
#  289           5.7          2.9           4.2          1.3  versicolor
#  2             5.1          3.5           1.4          0.2      setosa
#  324           6.7          2.5           5.8          1.8   virginica
#  218           6.3          2.5           4.9          1.5      setosa
#  ..            ...          ...           ...          ...         ...
#  100           5.5          4.2           1.4          0.2  versicolor
#  359           6.0          2.2           5.0          1.5      setosa
#  199           5.6          3.0           4.5          1.5  versicolor
#  113           4.9          3.6           1.4          0.1      setosa
#  420           6.7          3.1           5.6          2.4   virginica
#
#       versicolor  virginica
#  72            0          1
#  289           1          0
# ...

# %%
# identify the columns that are numeric
# then filter the df by those column names

num_cols = train.columns[[train[col].dtype != 'object' for col in train.columns]]
num_cols
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'versicolor', 'virginica'],
#       dtype='object')

# %%
# loop through each numeric column and plot a histogram and boxplot
# and compute descriptive stats.

# but before doing that, make it work for one variable

# histogram
col = 'sepal_length'
plt.hist(train[col])
plt.title(col)
plt.ylabel('frequency')
plt.show()
plt.boxplot(train[col])
plt.ylabel(col)
plt.show()
# descriptive statistics
train[col].describe()

for col in num_cols:
    
    plt.hist(train[col])
    plt.title(col)
    plt.ylabel('frequency')
    plt.show()
    plt.boxplot(train[col])
    plt.ylabel(col)
    plt.show()
    print(train[col].describe())
# Out:
# count    252.000000
# mean       5.838492
# std        0.808167
# min        4.300000
# 25%        5.100000
# 50%        5.800000
# 75%        6.400000
# max        7.900000
# Name: sepal_length, dtype: float64
# count    252.000000
# mean       3.056349
# std        0.427724
# min        2.000000
# 25%        2.800000
# 50%        3.000000
# 75%        3.300000
# max        4.400000
# Name: sepal_width, dtype: float64
# count    252.000000
# mean       3.751190
# std        1.744165
# min        1.100000
# 25%        1.600000
# 50%        4.400000
# 75%        5.100000
# max        6.900000
# Name: petal_length, dtype: float64
# count    252.000000
# mean       1.194048
# std        0.751098
# min        0.100000
# 25%        0.375000
# 50%        1.300000
# 75%        1.800000
# max        2.500000
# Name: petal_width, dtype: float64
# count    252.000000
# mean       0.333333
# std        0.472343
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# ...

# %% [markdown]
# **Takeaways**
#
# - sepal length and width are normally distributed
# - petal length and width are bimodal with wide inner quartile range

# %%
col='sepal_length'
sns.barplot(x='species', y=col, data=train)
plt.title(f'Average {col} for each species')
mean_sepal_length = train.sepal_length.mean()
plt.axhline(mean_sepal_length, label=f'Mean {col}', color='rebeccapurple', linestyle='dotted')
plt.legend()
plt.show()

# %%
train.groupby('species').describe().T

col='sepal_length'

for col in num_cols:
    
    sns.barplot(x='species', y=col, data=train)
    plt.title(f'Average {col} for each species')
    overall_mean = train[col].mean()
    plt.axhline(overall_mean, label=f'Mean {col}', color='rebeccapurple', linestyle='dotted')
    plt.legend()
    plt.show()
train.groupby('species').describe().T
# Out:
# species                setosa  versicolor  virginica
# sepal_length count  84.000000   84.000000  84.000000
#              mean    5.933333    5.767857   5.814286
#              std     0.835123    0.778346   0.810643
#              min     4.400000    4.400000   4.300000
#              25%     5.175000    5.100000   5.100000
#              50%     5.950000    5.700000   5.800000
#              75%     6.500000    6.400000   6.400000
#              max     7.900000    7.600000   7.700000
# sepal_width  count  84.000000   84.000000  84.000000
#              mean    3.069048    3.050000   3.050000
#              std     0.404486    0.441929   0.440564
#              min     2.000000    2.000000   2.200000
#              25%     2.800000    2.800000   2.800000
#              50%     3.000000    3.000000   3.000000
#              75%     3.300000    3.300000   3.225000
#              max     4.000000    4.200000   4.400000
# petal_length count  84.000000   84.000000  84.000000
# ...

# %% [markdown]
# **Takeaways**
#
# - sepal lenght: Virginica - longest, Setosa - shortest
# - sepal width: versicolor shortes, setosa - longest
# - petal length: virginica much longer, setosa - much shorter
# - petal width: virginica much longer, setosa - much shorter
# - It seems like it will be pretty easy to distinguish between virginica and setosa, but versicolor may blend between the two.
# - setosa can be classified by using petal_length alone.

# %% [markdown]
# H_0: There is no difference in the mean petal width for virginica vs veriscolor
# H_a: There is a significant difference in the mean petal width for virginica vs veriscolor

# %%
alpha = .05
t, p = stats.mannwhitneyu(train[train.species=='virginica'].petal_width, train[train.species=='versicolor'].petal_width)
if p < alpha:
    print('Reject null hpothesis, there is a significant difference')
    print('p-value', p)
else:
    print('There is not enough evidence to reject the null hypothesis')
    print('p-value', p)
print(p)
# Out:
# There is not enough evidence to reject the null hypothesis
# p-value 0.8646038701977478
# 0.8646038701977478

# %% [markdown]
# 2. Univariate Stats
# - For each measurement type (quantitative variable): create a histogram, boxplot, & compute descriptive statistics (using .describe()).

# %%
num_vars = iris.select_dtypes(include=['int64', 'float64'])

# %%
for col in num_vars:
    print(col)
    print(train[col].value_counts())
    print(train[col].value_counts(normalize=True)*100)
    sns.histplot(x=col, data=train)
    plt.show()
# Out:
# sepal_length
# 5.0    19
# 6.3    18
# 5.1    14
# 6.4    14
# 6.7    13
# 5.5    13
# 5.6    13
# 4.9    12
# 5.4    11
# 4.8    10
# 5.8    10
# 6.5     9
# 6.1     9
# 6.8     8
# 6.0     8
# 5.7     8
# 5.2     6
# 6.9     6
# 6.2     6
# 4.6     5
# 4.4     5
# 7.2     5
# 7.7     5
# 5.9     5
# 6.6     4
# 4.7     3
# 7.6     2
# 7.0     2
# 7.3     2
# 5.3     2
# 4.5     1
# 7.4     1
# 7.9     1
# 4.3     1
# 7.1     1
# Name: sepal_length, dtype: int64
# 5.0    7.539683
# 6.3    7.142857
# 5.1    5.555556
# 6.4    5.555556
# 6.7    5.158730
# 5.5    5.158730
# 5.6    5.158730
# 4.9    4.761905
# 5.4    4.365079
# 4.8    3.968254
# 5.8    3.968254
# 6.5    3.571429
# 6.1    3.571429
# 6.8    3.174603
# 6.0    3.174603
# 5.7    3.174603
# 5.2    2.380952
# 6.9    2.380952
# 6.2    2.380952
# 4.6    1.984127
# 4.4    1.984127
# 7.2    1.984127
# 7.7    1.984127
# 5.9    1.984127
# 6.6    1.587302
# 4.7    1.190476
# 7.6    0.793651
# 7.0    0.793651
# 7.3    0.793651
# ...

# %% [markdown]
# # Review

# %% [markdown]
# - For each species (categorical variable): create a frequency table and a bar plot of those frequencies.

# %%
alpha = .05
observed = pd.crosstab(train.versicolor, train.virginica)

chi2, p, degf, expected = stats.chi2_contingency(observed)

if p < alpha:
    print("Reject the null hypothesis")
    print("Sufficient evidence to move forward")
else:
    print("Fail to reject the null")
    print("Insufficient evidence to reject the null")
# Out:
# Reject the null hypothesis
# Sufficient evidence to move forward

# %%
plt.title("Versicolor vs Virginica")
sns.barplot(x="versicolor", y="virginica", data=train)
versicolor_virginica = train.virginica.mean()
plt.axhline(versicolor_virginica, label="versicolor vs. virginica")
plt.legend()
plt.show()

# %% [markdown]
# # Review

# %% [markdown]
# - Document takeaways & any actions.

# %% [markdown]
# **Takeaways:**.
#
# - There is a relationship between virginica and versicolor.
# - The pedal width and length may also be used in determining species type.

# %% [markdown]
# # Review

# %% [markdown]
# 3. Bivariate Stats
#
# - Visualize each measurement type (y-axis) with the species variable (x-axis) using barplots, adding a horizontal line showing the overall mean of the metric (y-axis).

# %%
iris.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# versicolor        uint8
# virginica         uint8
# dtype: object

# %%
cat_vars = iris.select_dtypes(include=['uint8'])
cat_vars
# Out:
#      versicolor  virginica
# 0             0          1
# 1             1          0
# 2             0          0
# 3             0          1
# 4             1          0
# ..          ...        ...
# 445           1          0
# 446           0          0
# 447           0          1
# 448           1          0
# 449           0          0
#
# [450 rows x 2 columns]

# %%
plt.title("Visualization of sepal length and species")
sns.barplot(x='species', y='sepal_length', data=train)
sepal_leng_avg = train.sepal_length.mean()
plt.axhline(sepal_leng_avg, label="overall mean of sepal length")
plt.legend()
plt.show()

plt.title("Visualization of sepal width and species")
sns.barplot(x='species', y='sepal_width', data=train)
sepal_wid_avg = train.sepal_width.mean()
plt.axhline(sepal_wid_avg, label="overall mean of sepal widthg")
plt.legend()
plt.show()

plt.title("Visualization of petal length and species")
sns.barplot(x='species', y='petal_length', data=train)
petal_leng_avg = train.petal_length.mean()
plt.axhline(petal_leng_avg, label="overall mean of petal length")
plt.legend()
plt.show()

plt.title("Visualization of petal width and species")
sns.barplot(x='species', y='petal_width', data=train)
petal_wid_avg = train.petal_width.mean()
plt.axhline(petal_wid_avg, label="overall mean of petal width")
plt.legend()
plt.show()

# %% [markdown]
# # Review

# %% [markdown]
# - For each measurement type, compute the descriptive statistics for each species.

# %%
iris.species.describe().T
# Out:
# count           450
# unique            3
# top       virginica
# freq            150
# Name: species, dtype: object

# %% [markdown]
# # Review

# %% [markdown]
# - For virginica & versicolor: Compare the mean petal_width using the Mann-Whitney test (scipy.stats.mannwhitneyu) to see if there is a significant difference between the two groups. Do the same for the other measurement types.

# %%
iris.head(2)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width     species  \
# 0           5.1          3.5           1.4          0.2   virginica
# 1           5.1          3.5           1.4          0.2  versicolor
#
#    versicolor  virginica
# 0           0          1
# 1           1          0

# %%
virginica = train[train.species == 'virginica']
versicolor = train[train.species == 'versicolor']
t, p = stats.mannwhitneyu(virginica.petal_width, versicolor.petal_width, alternative="greater")
t, p
# Out:
# (3474.0, 0.5689508901093551)

# %%
t, p = stats.mannwhitneyu(virginica.petal_length, versicolor.petal_length, alternative="greater")
t, p
# Out:
# (3539.0, 0.4866953236085891)

# %%
t, p = stats.mannwhitneyu(virginica.sepal_width, versicolor.sepal_width, alternative="greater")
t, p
# Out:
# (3478.5, 0.5632762842249682)

# %%
t, p = stats.mannwhitneyu(virginica.sepal_length, versicolor.sepal_length, alternative="greater")
t, p
# Out:
# (3605.5, 0.4034101289244034)

# %% [markdown]
# # Review

# %%
sns.pairplot(data=train, hue='species')
plt.show()

# %% [markdown]
# **Takeaways**
#
# - petal length and petal width can be used to distinguish setosa from the others, and
# can be helpful for the other two.
# - Setosa has the shortest petal length and width.
# - Virginica has the longest of both of those.
# - Sepal length can also help separate virginica and versicolor, as virginica is slightly shorter.
# - Virginica and versicolr overlap in sepal width

# %%
train['sepal_area'] = train.sepal_length * train.sepal_width
train['petal_area'] = train.petal_length * train.petal_width

sns.relplot(x='sepal_area', y='petal_area', data=train, hue='species')
plt.show()

# %%
cols_to_drop = ['versicolor', 'virginica']
train = train.drop(columns=cols_to_drop)
train.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species  \
# 72            4.8          3.4           1.9          0.2   virginica
# 289           5.7          2.9           4.2          1.3  versicolor
# 2             5.1          3.5           1.4          0.2      setosa
# 324           6.7          2.5           5.8          1.8   virginica
# 218           6.3          2.5           4.9          1.5      setosa
#
#      sepal_area  petal_area
# 72        16.32        0.38
# 289       16.53        5.46
# 2         17.85        0.28
# 324       16.75       10.44
# 218       15.75        7.35

# %%
melted = train.melt(id_vars=['species'], var_name='measures', value_name='values')
plt.title('Difference in measurements across species')
sns.swarmplot(x='measures', y='values', data=melted, hue='species')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# - Document takeaways & any actions.

# %% [markdown]
# **Takeaways**
#
# - There is a significant difference in all measurements between virginica and versicolor

# %% [markdown]
# 4. Multivariate Stats
#
# - Visualize the interaction of each measurement type with the others using a pairplot (or scatter matrix or something similar) and add color to represent species.

# %%
sns.pairplot(
    iris, hue='species',
    x_vars=['species'],
    y_vars=['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
)

# %% [markdown]
# - Visualize two numeric variables of the species. Hint: sns.relplot with hue or col

# %%
sns.relplot(x='sepal_length', y='petal_width', data=train, hue="species")

# %% [markdown]
# - Create a swarmplot using a melted dataframe of all your numeric variables. The x-axis should be the variable name, the y-axis the measure. Add another dimension using color to represent species. Document takeaways from this visualization.

# %%
sns.swarmplot(
    data=iris, 
    x='species',
    y=('sepal_length', 'sepal_width', 'petal_length', 'petal_width'), hue='species')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/2g/_40bymd11_x47n42bls8ypmr0000gn/T/ipykernel_2563/2422845223.py in <module>
# ----> 1 sns.swarmplot(
#       2     data=iris,
#       3     x='species',
#       4     y=('sepal_length', 'sepal_width', 'petal_length', 'petal_width'), hue='species')
#
# /usr/local/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py in swarmplot(x, y, hue, data, order, hue_order, dodge, orient, color, palette, size, edgecolor, linewidth, ax, **kwargs)
#    3002         warnings.warn(msg, UserWarning)
#    3003
# ...

# %% [markdown]
# - Ask a specific question of the data, such as: is the sepal area signficantly different in virginica compared to setosa? Answer the question through both a plot and using a mann-whitney or t-test. If you use a t-test, be sure assumptions are met (independence, normality, equal variance).

# %% [markdown]
# - Document takeaways and any actions.

# %% [markdown]
# Part II
# Explore your titanic dataset more completely.

# %%
# Is the impact of traveling alone different based on sex?

import env

def get_connection(db, username=env.username, host=env.host, password=env.password):
    return f'mysql+pymysql://{username}:{password}@{host}/{db}'

def get_titanic():
    my_query="SELECT * FROM passengers"
    titanic = pd.read_sql(my_query, get_connection('titanic_db'))
    return titanic

# %%
titanic = titanic.drop(columns=['age', 'deck', 'embark_town'])
titanic = titanic[~titanic.embark.isna()]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/2g/_40bymd11_x47n42bls8ypmr0000gn/T/ipykernel_852/2343154611.py in <module>
# ----> 1 titanic = titanic.drop(columns=['age', 'deck', 'embark_town'])
#       2 titanic = titanic[~titanic.embark.isna()]
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ...

# %%
train, validate, test = train_validate_test_split(titanic, target='survived')
train.shape, validate.shape, test.shape
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   sex          891 non-null    object
#  2   age          714 non-null    float64
#  3   sibsp        891 non-null    int64
#  4   parch        891 non-null    int64
#  5   fare         891 non-null    float64
#  6   class        891 non-null    object
#  7   deck         203 non-null    object
#  8   embark_town  889 non-null    object
#  9   alone        891 non-null    int64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 69.7+ KB

# %%
cat_vars = ['class', 'sex', 'sibsp', 'parch', 'alone']
col = 'class'
sns.barplot(x=col, y='survived', data=train)
plt.show()

for col in cat_vars:
    plt.title(f'Rate of survival for each {col}')
    sns.barplot(x=col, y='survived', data=train)
    plt.show()

# %% [markdown]
# **Takeaways**
#
# More likely to survive (based on visualizationas)
#
# - first class
# - women
# - traveling alone
# - one sibling or spouse
#
# Drivers = sex, class, alone, sibling/spouse

# %% [markdown]
# **Is the impact of traveilng alone different based on sex?**

# %%
female = train[train.sex=='female']
male = train[train.sex=='male']

sns.barplot(x='alone', y='survived', data=train, hue='sex')
plt.show()
# It looks like being alone only impacts males, who are less likely to survive in that case

# %% [markdown]
# **Does class impact the survival rate of males or females?**

# %%
sns.barplot(x='class', y='survived', data=train, hue='sex')
plt.show()

# the females who didn't survive appear to be in 3rd class.
# if a male survived, he was likely in 1st class

# %% [markdown]
# **Takeaways**
#
# ### the females who didn't survive appear to be in 3rd class.
# ### if a male survived, he was likely in 1st class

# %% [markdown]
# **of the females in 3rd class, were they more likely to survive if they were alone or not alone(or neither)?**

# %%
sns.barplot(x='class', y='survived', data = train[train.sex=='female'], hue='alone')
plt.show()

# %% [markdown]
# **Takeways**
#
# - females in third class appear more likely to survive if they were traveling alone

# %%
# H_0: survival rate of females in 3rd class alone <= survival rate of females in 3rd class not alone


alpha = .05

# %%
sample = train[(train['class'] == 'third') & (train['sex'] == 'female')]
observed = pd.crosstab(sample.alone, sample.survived)
stats.chi2_contingency(observed)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/2g/_40bymd11_x47n42bls8ypmr0000gn/T/ipykernel_852/765215614.py in <module>
#       1 sample = train[(train['class'] == 'third') & (train['sex'] == 'female')]
#       2 observed = pd.crosstab(sample.alone, sample.survived)
# ----> 3 stats.chi2_contingency(observed)
#
# /usr/local/anaconda3/lib/python3.9/site-packages/scipy/stats/contingency.py in chi2_contingency(observed, correction, lambda_)
#     267         raise ValueError("All values in `observed` must be nonnegative.")
#     268     if observed.size == 0:
# --> 269         raise ValueError("No data; `observed` has size 0.")
#     270
#     271     expected = expected_freq(observed)
#
# ValueError: No data; `observed` has size 0.

# %% [markdown]
# - Determine drivers of the target variable

# %%
titanic = get_titanic()
titanic.head(2)
# Out:
#    passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
#
#   embarked  class  deck  embark_town  alone
# 0        S  Third  None  Southampton      0
# 1        C  First     C    Cherbourg      0

# %% [markdown]
# - Determine if certain columns should be dropped

# %%
cols_to_drop = ['passenger_id', 'pclass', 'embarked']
titanic = titanic.drop(columns=cols_to_drop)
titanic.head()
# Out:
#    survived     sex   age  sibsp  parch     fare  class  deck  embark_town  \
# 0         0    male  22.0      1      0   7.2500  Third  None  Southampton
# 1         1  female  38.0      1      0  71.2833  First     C    Cherbourg
# 2         1  female  26.0      0      0   7.9250  Third  None  Southampton
# 3         1  female  35.0      1      0  53.1000  First     C  Southampton
# 4         0    male  35.0      0      0   8.0500  Third  None  Southampton
#
#    alone
# 0      0
# 1      0
# 2      1
# 3      0
# 4      1

# %% [markdown]
# - Determine if it would be valuable to bin some numeric columns

# %%
titanic.dtypes
# Out:
# survived         int64
# sex             object
# age            float64
# sibsp            int64
# parch            int64
# fare           float64
# class           object
# deck            object
# embark_town     object
# alone            int64
# dtype: object

# %%
num_vars = titanic.select_dtypes(include=['int64', 'float64'])
num_vars
# Out:
#      survived   age  sibsp  parch     fare  alone
# 0           0  22.0      1      0   7.2500      0
# 1           1  38.0      1      0  71.2833      0
# 2           1  26.0      0      0   7.9250      1
# 3           1  35.0      1      0  53.1000      0
# 4           0  35.0      0      0   8.0500      1
# ..        ...   ...    ...    ...      ...    ...
# 886         0  27.0      0      0  13.0000      1
# 887         1  19.0      0      0  30.0000      1
# 888         0   NaN      1      2  23.4500      0
# 889         1  26.0      0      0  30.0000      1
# 890         0  32.0      0      0   7.7500      1
#
# [891 rows x 6 columns]

# %% [markdown]
# - Determine if it would be valuable to combine multiple columns into one.

# %% [markdown]
# Does it make sense to combine any features?

# %% [markdown]
# Do you find any surprises?

# %% [markdown]
# Document any and all findings and takeaways in your notebook using markdown.

# %% [markdown]
# Part III
# - Explore your telco data to discover drivers of churn

# %%
def get_connection(db, username=env.username, host=env.host, password=env.password):
    return f'mysql+pymysql://{username}:{password}@{host}/{db}'

def get_telco():
    my_query="SELECT * FROM customers JOIN contract_types JOIN internet_service_types JOIN payment_types"
    telco = pd.read_sql(my_query, get_connection('telco_churn'))
    return telco

# %%
telco = get_telco()
telco.head(2)
# Out:
#   customer_id  gender  senior_citizen partner dependents  tenure  \
# 0  0002-ORFBO  Female               0     Yes        Yes       9
# 1  0002-ORFBO  Female               0     Yes        Yes       9
#
#   phone_service multiple_lines internet_service_type_id online_security  ...  \
# 0           Yes             No                        1              No  ...
# 1           Yes             No                        1              No  ...
#
#    payment_type_id monthly_charges total_charges churn contract_type_id  \
# 0                2            65.6         593.3    No                3
# 1                2            65.6         593.3    No                2
#
#    contract_type internet_service_type_id  internet_service_type  \
# 0       Two year                        1                    DSL
# 1       One year                        1                    DSL
#
#    payment_type_id             payment_type
# 0                4  Credit card (automatic)
# ...

# %% [markdown]
# - Determine if certain columns should be dropped

# %%
cols_to_drop = ['internet_service_type_id', 'payment_type_id', 'contract_type_id', 'internet_service_type_id', 'payment_type_id']
telco = telco.drop(columns=cols_to_drop)
telco.head()
# Out:
#   customer_id  gender  senior_citizen partner dependents  tenure  \
# 0  0002-ORFBO  Female               0     Yes        Yes       9
# 1  0002-ORFBO  Female               0     Yes        Yes       9
# 2  0002-ORFBO  Female               0     Yes        Yes       9
# 3  0002-ORFBO  Female               0     Yes        Yes       9
# 4  0002-ORFBO  Female               0     Yes        Yes       9
#
#   phone_service multiple_lines online_security online_backup  ...  \
# 0           Yes             No              No           Yes  ...
# 1           Yes             No              No           Yes  ...
# 2           Yes             No              No           Yes  ...
# 3           Yes             No              No           Yes  ...
# 4           Yes             No              No           Yes  ...
#
#   tech_support streaming_tv streaming_movies paperless_billing  \
# 0          Yes          Yes               No               Yes
# ...

# %% [markdown]
# - Determine if it would be valuable to bin some numeric columns

# %%
telco.dtypes
# Out:
# customer_id               object
# gender                    object
# senior_citizen             int64
# partner                   object
# dependents                object
# tenure                     int64
# phone_service             object
# multiple_lines            object
# online_security           object
# online_backup             object
# device_protection         object
# tech_support              object
# streaming_tv              object
# streaming_movies          object
# paperless_billing         object
# monthly_charges          float64
# total_charges             object
# churn                     object
# contract_type             object
# internet_service_type     object
# payment_type              object
# dtype: object

# %% [markdown]
# - Determine if it would be valuable to combine multiple columns into one.

# %% [markdown]
# What are your drivers of churn?

# %% [markdown]
# Does it make sense to combine any features?

# %% [markdown]
# Do you find any surprises?

# %% [markdown]
# Document any and all findings and takeaways in your notebook using markdown.
